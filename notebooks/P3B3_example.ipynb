# %% [markdown]
# This is an example for running the FrESCO library with the P3B3 becnhmark data from the ECP-Candle [repository](https://github.com/ECP-CANDLE/Benchmarks). Included within the FrESCO repository is a preformatted version of the P3B3 dataset for model training. If you've not already done so, go to the data directory and unzip the dataset using the command `$ tar -xf P3B3.tar.gz`.

# %% [markdown]
# In the `configs/` directory are sample `model_args.yml` files for the three sample datasets, using the default settings in these files, we are ready to train a model.

# %%
import fresco
import argparse

# %% [markdown]
# The FrESCO library is typically run from the command line with arguments specifying the model type and model args, so we'll have to set them up manually for this notebook.

# %%
    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    _ = parser.add_argument("--model", "-m", type=str, default='ie',
                        help="""which type of model to create. Must be either
                                IE (information extraction) or clc (case-level context).""")
    _ = parser.add_argument('--model_path', '-mp', type=str, default='',
                       help="""this is the location of the model
                               that will used to make predictions""")
    _ = parser.add_argument('--data_path', '-dp', type=str, default='',
                        help="""where the data will load from. The default is
                                the path saved in the model""")
    _ = parser.add_argument('--model_args', '-args', type=str, default='',
                        help="""file specifying the model or clc args; default is in
                                the fresco directory""")

# %% [markdown]
# We are going to train a multi-task classification model on the P3B3 dataset, so we'll specify an `information extraction` model and point to the P3B3 model args file.

# %%
args = parser.parse_args(args=['-m', 'ie', '-args', '../configs/P3B3_args.yml'])

# %% [markdown]
# With these arguments specified, just need a few imports before we're ready to train our model.

# %%
from fresco import run_ie

from fresco.validate import exceptions

# %%
run_ie.run_ie(args)
# Out:
# Validating kwargs in model_args.yml file
# Word embeddings file does not exist; will default to random embeddings.
# Loading data and creating DataLoaders
# Loading data from ../data/P3B3/
# Num workers: 4, reproducible: True
# Training on 7500 validate on 1500
#
# Defining a model
# Creating model trainer
# Training a mthisan model with 2 cuda device
#
#
# epoch: 1
#
# training time 10.13
# Training loss: 0.861854
#         task:      micro        macro
#       task_1:     0.5047,     0.0645
#       task_2:     0.5552,     0.4172
#       task_3:     0.8787,     0.4795
#       task_4:     0.4424,     0.2964
#
# epoch 1 validation
#
# epoch 1 val loss: 1.17360581, best val loss: inf
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5453,     0.0602
#       task_2:     0.5733,     0.4001
#       task_3:     0.8787,     0.4784
#       task_4:     0.4640,     0.3259
#
# epoch: 2
#
# training time 8.88
# Training loss: 0.871779
#         task:      micro        macro
#       task_1:     0.5504,     0.1189
#       task_2:     0.5509,     0.4295
#       task_3:     0.8913,     0.4713
#       task_4:     0.4471,     0.3045
#
# epoch 2 validation
#
# epoch 2 val loss: 1.09017822, best val loss: 1.17360581
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5480,     0.0887
#       task_2:     0.5680,     0.3787
#       task_3:     0.8853,     0.4696
#       task_4:     0.4640,     0.3071
#
# epoch: 3
#
# training time 8.88
# Training loss: 0.858503
#         task:      micro        macro
#       task_1:     0.5501,     0.1185
#       task_2:     0.5495,     0.4433
#       task_3:     0.8913,     0.4713
#       task_4:     0.4440,     0.3008
#
# epoch 3 validation
#
# epoch 3 val loss: 1.02599622, best val loss: 1.09017822
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5473,     0.0886
#       task_2:     0.5653,     0.3695
#       task_3:     0.8853,     0.4696
#       task_4:     0.4640,     0.2923
#
# epoch: 4
#
# training time 9.03
# Training loss: 0.906322
#         task:      micro        macro
#       task_1:     0.5488,     0.1187
#       task_2:     0.5517,     0.4688
#       task_3:     0.8913,     0.4713
#       task_4:     0.4437,     0.3029
#
# epoch 4 validation
#
# epoch 4 val loss: 0.97310692, best val loss: 1.02599622
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5493,     0.1023
#       task_2:     0.5673,     0.3703
#       task_3:     0.8860,     0.4698
#       task_4:     0.4273,     0.2234
#
# epoch: 5
#
# training time 9.04
# Training loss: 0.833718
#         task:      micro        macro
#       task_1:     0.5501,     0.1203
#       task_2:     0.5527,     0.4538
#       task_3:     0.8913,     0.4713
#       task_4:     0.4504,     0.3104
#
# epoch 5 validation
#
# epoch 5 val loss: 0.93313286, best val loss: 0.97310692
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5500,     0.1023
#       task_2:     0.5660,     0.3656
#       task_3:     0.8853,     0.4696
#       task_4:     0.4387,     0.2401
#
# epoch: 6
#
# training time 9.13
# Training loss: 0.795575
#         task:      micro        macro
#       task_1:     0.5500,     0.1187
#       task_2:     0.5597,     0.4379
#       task_3:     0.8913,     0.4713
#       task_4:     0.4484,     0.3049
#
# epoch 6 validation
#
# epoch 6 val loss: 0.90652677, best val loss: 0.93313286
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5493,     0.1023
#       task_2:     0.5667,     0.3673
#       task_3:     0.8853,     0.4696
#       task_4:     0.4280,     0.2192
#
# epoch: 7
#
# training time 9.12
# Training loss: 0.857706
#         task:      micro        macro
#       task_1:     0.5495,     0.1184
#       task_2:     0.5533,     0.4408
#       task_3:     0.8913,     0.4713
#       task_4:     0.4529,     0.3131
#
# epoch 7 validation
#
# epoch 7 val loss: 0.87840221, best val loss: 0.90652677
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5493,     0.1023
#       task_2:     0.5700,     0.3822
#       task_3:     0.8853,     0.4696
#       task_4:     0.4440,     0.2435
#
# epoch: 8
#
# training time 9.11
# Training loss: 0.885486
#         task:      micro        macro
#       task_1:     0.5500,     0.1185
#       task_2:     0.5667,     0.4572
#       task_3:     0.8913,     0.4713
#       task_4:     0.4449,     0.2966
#
# epoch 8 validation
#
# epoch 8 val loss: 0.85413995, best val loss: 0.87840221
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5487,     0.1031
#       task_2:     0.5693,     0.3819
#       task_3:     0.8853,     0.4696
#       task_4:     0.4553,     0.2601
#
# epoch: 9
#
# training time 9.14
# Training loss: 0.816049
#         task:      micro        macro
#       task_1:     0.5507,     0.1192
#       task_2:     0.5851,     0.4579
#       task_3:     0.8913,     0.4713
#       task_4:     0.4585,     0.3062
#
# epoch 9 validation
#
# epoch 9 val loss: 0.81856253, best val loss: 0.85413995
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.5773,     0.1377
#       task_2:     0.6167,     0.4938
#       task_3:     0.8853,     0.4696
#       task_4:     0.5113,     0.3430
#
# epoch: 10
#
# training time 9.14
# Training loss: 0.746979
#         task:      micro        macro
#       task_1:     0.5705,     0.1563
#       task_2:     0.7517,     0.7366
#       task_3:     0.8913,     0.4713
#       task_4:     0.4669,     0.3189
#
# epoch 10 validation
#
# epoch 10 val loss: 0.73360504, best val loss: 0.81856253
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.6560,     0.2032
#       task_2:     0.8707,     0.8685
#       task_3:     0.8860,     0.4698
#       task_4:     0.5727,     0.4105
#
# epoch: 11
#
# training time 9.15
# Training loss: 0.752350
#         task:      micro        macro
#       task_1:     0.6055,     0.1980
#       task_2:     0.8516,     0.8505
#       task_3:     0.8913,     0.4713
#       task_4:     0.4815,     0.3310
#
# epoch 11 validation
#
# epoch 11 val loss: 0.71064045, best val loss: 0.73360504
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.6620,     0.2068
#       task_2:     0.8733,     0.8722
#       task_3:     0.8860,     0.4698
#       task_4:     0.5033,     0.3336
#
# epoch: 12
#
# training time 9.24
# Training loss: 0.701709
#         task:      micro        macro
#       task_1:     0.6483,     0.2281
#       task_2:     0.8517,     0.8503
#       task_3:     0.8915,     0.4750
#       task_4:     0.5057,     0.3646
#
# epoch 12 validation
#
# epoch 12 val loss: 0.68655752, best val loss: 0.71064045
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.6913,     0.2165
#       task_2:     0.8713,     0.8702
#       task_3:     0.8860,     0.4698
#       task_4:     0.5427,     0.4337
#
# epoch: 13
#
# training time 9.15
# Training loss: 0.601671
#         task:      micro        macro
#       task_1:     0.6944,     0.2529
#       task_2:     0.8583,     0.8566
#       task_3:     0.8909,     0.4736
#       task_4:     0.5253,     0.4024
#
# epoch 13 validation
#
# epoch 13 val loss: 0.64462133, best val loss: 0.68655752
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7180,     0.2257
#       task_2:     0.8793,     0.8784
#       task_3:     0.8860,     0.4755
#       task_4:     0.5320,     0.4977
#
# epoch: 14
#
# training time 9.19
# Training loss: 0.577315
#         task:      micro        macro
#       task_1:     0.7195,     0.2736
#       task_2:     0.8617,     0.8599
#       task_3:     0.8907,     0.4771
#       task_4:     0.5441,     0.4687
#
# epoch 14 validation
#
# epoch 14 val loss: 0.60018223, best val loss: 0.64462133
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7280,     0.2291
#       task_2:     0.8893,     0.8885
#       task_3:     0.8840,     0.4749
#       task_4:     0.5433,     0.5133
#
# epoch: 15
#
# training time 9.16
# Training loss: 0.496693
#         task:      micro        macro
#       task_1:     0.7373,     0.3200
#       task_2:     0.8836,     0.8814
#       task_3:     0.8908,     0.4899
#       task_4:     0.5553,     0.4928
#
# epoch 15 validation
#
# epoch 15 val loss: 0.54817979, best val loss: 0.60018223
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7367,     0.2370
#       task_2:     0.9047,     0.9038
#       task_3:     0.8840,     0.5159
#       task_4:     0.5480,     0.5155
#
# epoch: 16
# training time 9.16
# Training loss: 0.494371
#         task:      micro        macro
#       task_1:     0.7556,     0.3816
#       task_2:     0.8983,     0.8958
#       task_3:     0.8931,     0.5128
#       task_4:     0.5675,     0.5025
#
# epoch 16 validation
#
# epoch 16 val loss: 0.52033003, best val loss: 0.54817979
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7400,     0.2499
#       task_2:     0.9100,     0.9091
#       task_3:     0.8867,     0.5360
#       task_4:     0.5500,     0.5287
#
# epoch: 17
#
# training time 9.15
# Training loss: 0.436824
#         task:      micro        macro
#       task_1:     0.7676,     0.4251
#       task_2:     0.9008,     0.8984
#       task_3:     0.8981,     0.5690
#       task_4:     0.5903,     0.5422
#
# epoch 17 validation
#
# epoch 17 val loss: 0.49516671, best val loss: 0.52033003
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7467,     0.2715
#       task_2:     0.9240,     0.9226
#       task_3:     0.9053,     0.7051
#       task_4:     0.5667,     0.5458
#
# epoch: 18
#
# training time 9.17
# Training loss: 0.427460
#         task:      micro        macro
#       task_1:     0.7773,     0.4473
#       task_2:     0.9057,     0.9030
#       task_3:     0.9053,     0.6313
#       task_4:     0.5999,     0.5503
#
# epoch 18 validation
#
# epoch 18 val loss: 0.47663346, best val loss: 0.49516671
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7533,     0.3021
#       task_2:     0.9267,     0.9253
#       task_3:     0.9187,     0.7714
#       task_4:     0.5840,     0.5585
#
# epoch: 19
#
# training time 9.16
# Training loss: 0.408075
#         task:      micro        macro
#       task_1:     0.7896,     0.4859
#       task_2:     0.9055,     0.9026
#       task_3:     0.9143,     0.6833
#       task_4:     0.6183,     0.5740
#
# epoch 19 validation
#
# epoch 19 val loss: 0.45452817, best val loss: 0.47663346
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7633,     0.3314
#       task_2:     0.9233,     0.9207
#       task_3:     0.9307,     0.8343
#       task_4:     0.6153,     0.5896
#
# epoch: 20
#
# training time 9.15
# Training loss: 0.495157
#         task:      micro        macro
#       task_1:     0.7956,     0.5087
#       task_2:     0.9067,     0.9038
#       task_3:     0.9253,     0.7487
#       task_4:     0.6412,     0.5877
#
# epoch 20 validation
#
# epoch 20 val loss: 0.43712290, best val loss: 0.45452817
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7660,     0.3574
#       task_2:     0.9260,     0.9239
#       task_3:     0.9407,     0.8543
#       task_4:     0.6240,     0.5927
#
# epoch: 21
#
# training time 9.18
# Training loss: 0.337863
#         task:      micro        macro
#       task_1:     0.8063,     0.5512
#       task_2:     0.9104,     0.9075
#       task_3:     0.9359,     0.7984
#       task_4:     0.6636,     0.6252
#
# epoch 21 validation
#
# epoch 21 val loss: 0.42223409, best val loss: 0.43712290
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7727,     0.3761
#       task_2:     0.9300,     0.9282
#       task_3:     0.9487,     0.8758
#       task_4:     0.6400,     0.6152
#
# epoch: 22
#
# training time 9.16
# Training loss: 0.460756
#         task:      micro        macro
#       task_1:     0.8124,     0.5787
#       task_2:     0.9113,     0.9087
#       task_3:     0.9460,     0.8353
#       task_4:     0.6795,     0.6404
#
# epoch 22 validation
#
# epoch 22 val loss: 0.40528843, best val loss: 0.42223409
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.7800,     0.4129
#       task_2:     0.9267,     0.9245
#       task_3:     0.9500,     0.8813
#       task_4:     0.6660,     0.6395
#
# epoch: 23
#
# training time 9.17
# Training loss: 0.387836
#         task:      micro        macro
#       task_1:     0.8247,     0.6229
#       task_2:     0.9140,     0.9112
#       task_3:     0.9511,     0.8564
#       task_4:     0.6947,     0.6607
#
# epoch 23 validation
#
# epoch 23 val loss: 0.38393665, best val loss: 0.40528843
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8073,     0.4890
#       task_2:     0.9267,     0.9245
#       task_3:     0.9500,     0.8819
#       task_4:     0.6933,     0.6639
#
# epoch: 24
#
# training time 9.14
# Training loss: 0.337573
#         task:      micro        macro
#       task_1:     0.8399,     0.6661
#       task_2:     0.9108,     0.9080
#       task_3:     0.9527,     0.8617
#       task_4:     0.7048,     0.6716
#
# epoch 24 validation
#
# epoch 24 val loss: 0.36712197, best val loss: 0.38393665
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8313,     0.5600
#       task_2:     0.9300,     0.9278
#       task_3:     0.9560,     0.8978
#       task_4:     0.7173,     0.6899
#
# epoch: 25
#
# training time 9.16
# Training loss: 0.320473
#         task:      micro        macro
#       task_1:     0.8508,     0.7033
#       task_2:     0.9141,     0.9114
#       task_3:     0.9604,     0.8867
#       task_4:     0.7085,     0.6732
#
# epoch 25 validation
#
# epoch 25 val loss: 0.35720478, best val loss: 0.36712197
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8493,     0.6018
#       task_2:     0.9293,     0.9272
#       task_3:     0.9533,     0.8931
#       task_4:     0.7293,     0.7025
#
# epoch: 26
#
# training time 9.16
# Training loss: 0.344269
#         task:      micro        macro
#       task_1:     0.8509,     0.7035
#       task_2:     0.9136,     0.9109
#       task_3:     0.9625,     0.8935
#       task_4:     0.7284,     0.6975
#
# epoch 26 validation
#
# epoch 26 val loss: 0.34574795, best val loss: 0.35720478
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8633,     0.6256
#       task_2:     0.9267,     0.9245
#       task_3:     0.9553,     0.8984
#       task_4:     0.7340,     0.7021
#
# epoch: 27
#
# training time 9.16
# Training loss: 0.295445
#         task:      micro        macro
#       task_1:     0.8647,     0.7403
#       task_2:     0.9149,     0.9124
#       task_3:     0.9619,     0.8918
#       task_4:     0.7287,     0.6981
#
# epoch 27 validation
#
# epoch 27 val loss: 0.33832929, best val loss: 0.34574795
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8813,     0.6617
#       task_2:     0.9320,     0.9302
#       task_3:     0.9540,     0.8963
#       task_4:     0.7473,     0.7241
#
# epoch: 28
#
# training time 9.17
# Training loss: 0.267612
#         task:      micro        macro
#       task_1:     0.8727,     0.7550
#       task_2:     0.9172,     0.9146
#       task_3:     0.9679,     0.9110
#       task_4:     0.7501,     0.7225
#
# epoch 28 validation
#
# epoch 28 val loss: 0.32824610, best val loss: 0.33832929
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8900,     0.6797
#       task_2:     0.9333,     0.9318
#       task_3:     0.9593,     0.9062
#       task_4:     0.7573,     0.7335
#
# epoch: 29
#
# training time 9.14
# Training loss: 0.345664
#         task:      micro        macro
#       task_1:     0.8804,     0.7756
#       task_2:     0.9181,     0.9156
#       task_3:     0.9699,     0.9162
#       task_4:     0.7615,     0.7372
#
# epoch 29 validation
#
# epoch 29 val loss: 0.32410665, best val loss: 0.32824610
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.8987,     0.6900
#       task_2:     0.9320,     0.9304
#       task_3:     0.9613,     0.9142
#       task_4:     0.7713,     0.7549
#
# epoch: 30
#
# training time 9.15
# Training loss: 0.304864
#         task:      micro        macro
#       task_1:     0.8815,     0.7718
#       task_2:     0.9216,     0.9190
#       task_3:     0.9720,     0.9227
#       task_4:     0.7691,     0.7426
#
# epoch 30 validation
#
# epoch 30 val loss: 0.31153715, best val loss: 0.32410665
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9067,     0.7089
#       task_2:     0.9253,     0.9231
#       task_3:     0.9693,     0.9297
#       task_4:     0.7827,     0.7637
#
# epoch: 31
#
# training time 9.16
# Training loss: 0.272961
#         task:      micro        macro
#       task_1:     0.8868,     0.7894
#       task_2:     0.9197,     0.9173
#       task_3:     0.9733,     0.9264
#       task_4:     0.7904,     0.7695
#
# epoch 31 validation
# epoch 31 val loss: 0.30449256, best val loss: 0.31153715
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9107,     0.7133
#       task_2:     0.9293,     0.9274
#       task_3:     0.9647,     0.9207
#       task_4:     0.7913,     0.7717
#
# epoch: 32
#
# training time 9.15
# Training loss: 0.277118
#         task:      micro        macro
#       task_1:     0.8923,     0.7991
#       task_2:     0.9212,     0.9188
#       task_3:     0.9749,     0.9323
#       task_4:     0.7969,     0.7785
#
# epoch 32 validation
#
# epoch 32 val loss: 0.29556886, best val loss: 0.30449256
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9147,     0.7189
#       task_2:     0.9333,     0.9318
#       task_3:     0.9687,     0.9284
#       task_4:     0.8060,     0.7910
#
# epoch: 33
#
# training time 9.15
# Training loss: 0.293950
#         task:      micro        macro
#       task_1:     0.8956,     0.8082
#       task_2:     0.9201,     0.9177
#       task_3:     0.9760,     0.9344
#       task_4:     0.8023,     0.7867
#
# epoch 33 validation
#
# epoch 33 val loss: 0.29012900, best val loss: 0.29556886
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9200,     0.7262
#       task_2:     0.9300,     0.9281
#       task_3:     0.9647,     0.9207
#       task_4:     0.8140,     0.7934
#
# epoch: 34
#
# training time 9.14
# Training loss: 0.281818
#         task:      micro        macro
#       task_1:     0.8987,     0.8129
#       task_2:     0.9229,     0.9207
#       task_3:     0.9767,     0.9370
#       task_4:     0.8097,     0.7923
#
# epoch 34 validation
#
# epoch 34 val loss: 0.28112656, best val loss: 0.29012900
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9253,     0.8607
#       task_2:     0.9307,     0.9288
#       task_3:     0.9680,     0.9277
#       task_4:     0.8320,     0.8122
#
# epoch: 35
#
# training time 9.12
# Training loss: 0.234703
#         task:      micro        macro
#       task_1:     0.9029,     0.8231
#       task_2:     0.9215,     0.9191
#       task_3:     0.9763,     0.9359
#       task_4:     0.8209,     0.8000
#
# epoch 35 validation
#
# epoch 35 val loss: 0.28208673, best val loss: 0.28112656
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9260,     0.8620
#       task_2:     0.9313,     0.9298
#       task_3:     0.9693,     0.9301
#       task_4:     0.8360,     0.8238
#
# epoch: 36
#
# training time 9.15
# Training loss: 0.282682
#         task:      micro        macro
#       task_1:     0.9072,     0.8286
#       task_2:     0.9239,     0.9217
#       task_3:     0.9779,     0.9404
#       task_4:     0.8292,     0.8141
#
# epoch 36 validation
#
# epoch 36 val loss: 0.27305774, best val loss: 0.28112656
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9280,     0.8680
#       task_2:     0.9280,     0.9261
#       task_3:     0.9720,     0.9359
#       task_4:     0.8387,     0.8195
#
# epoch: 37
#
# training time 9.16
# Training loss: 0.182351
#         task:      micro        macro
#       task_1:     0.9104,     0.8355
#       task_2:     0.9201,     0.9179
#       task_3:     0.9801,     0.9462
#       task_4:     0.8353,     0.8190
#
# epoch 37 validation
#
# epoch 37 val loss: 0.27259806, best val loss: 0.27305774
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9307,     0.8717
#       task_2:     0.9333,     0.9318
#       task_3:     0.9720,     0.9359
#       task_4:     0.8433,     0.8294
#
# epoch: 38
#
# training time 9.15
# Training loss: 0.322571
#         task:      micro        macro
#       task_1:     0.9123,     0.8390
#       task_2:     0.9241,     0.9219
#       task_3:     0.9789,     0.9431
#       task_4:     0.8449,     0.8307
#
# epoch 38 validation
#
# epoch 38 val loss: 0.27089657, best val loss: 0.27259806
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9340,     0.8810
#       task_2:     0.9313,     0.9297
#       task_3:     0.9720,     0.9359
#       task_4:     0.8527,     0.8388
#
# epoch: 39
#
# training time 9.12
# Training loss: 0.268591
#         task:      micro        macro
#       task_1:     0.9164,     0.8511
#       task_2:     0.9275,     0.9255
#       task_3:     0.9796,     0.9454
#       task_4:     0.8532,     0.8381
#
# epoch 39 validation
#
# epoch 39 val loss: 0.26864657, best val loss: 0.27089657
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9340,     0.8795
#       task_2:     0.9320,     0.9305
#       task_3:     0.9720,     0.9361
#       task_4:     0.8633,     0.8515
#
# epoch: 40
#
# training time 9.13
# Training loss: 0.154677
#         task:      micro        macro
#       task_1:     0.9153,     0.8484
#       task_2:     0.9269,     0.9248
#       task_3:     0.9804,     0.9471
#       task_4:     0.8539,     0.8422
#
# epoch 40 validation
#
# epoch 40 val loss: 0.26188909, best val loss: 0.26864657
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9367,     0.8859
#       task_2:     0.9327,     0.9309
#       task_3:     0.9733,     0.9392
#       task_4:     0.8660,     0.8545
#
# epoch: 41
#
# training time 9.16
# Training loss: 0.178068
#         task:      micro        macro
#       task_1:     0.9212,     0.8615
#       task_2:     0.9236,     0.9216
#       task_3:     0.9840,     0.9572
#       task_4:     0.8596,     0.8489
#
# epoch 41 validation
#
# epoch 41 val loss: 0.26666158, best val loss: 0.26188909
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9380,     0.8871
#       task_2:     0.9327,     0.9311
#       task_3:     0.9727,     0.9381
#       task_4:     0.8627,     0.8507
#
# epoch: 42
#
# training time 9.16
# Training loss: 0.197937
#         task:      micro        macro
#       task_1:     0.9204,     0.8621
#       task_2:     0.9260,     0.9239
#       task_3:     0.9829,     0.9546
#       task_4:     0.8616,     0.8497
#
# epoch 42 validation
#
# epoch 42 val loss: 0.26179894, best val loss: 0.26188909
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9367,     0.8856
#       task_2:     0.9347,     0.9331
#       task_3:     0.9727,     0.9372
#       task_4:     0.8693,     0.8614
#
# epoch: 43
#
# training time 9.15
# Training loss: 0.197968
#         task:      micro        macro
#       task_1:     0.9261,     0.8713
#       task_2:     0.9263,     0.9243
#       task_3:     0.9828,     0.9540
#       task_4:     0.8700,     0.8595
#
# epoch 43 validation
#
# epoch 43 val loss: 0.26068287, best val loss: 0.26179894
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9360,     0.8846
#       task_2:     0.9327,     0.9312
#       task_3:     0.9740,     0.9406
#       task_4:     0.8740,     0.8636
#
# epoch: 44
#
# training time 9.14
# Training loss: 0.179261
#         task:      micro        macro
#       task_1:     0.9267,     0.8723
#       task_2:     0.9291,     0.9270
#       task_3:     0.9820,     0.9521
#       task_4:     0.8751,     0.8624
#
# epoch 44 validation
#
# epoch 44 val loss: 0.26405376, best val loss: 0.26068287
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9393,     0.8907
#       task_2:     0.9327,     0.9311
#       task_3:     0.9733,     0.9395
#       task_4:     0.8740,     0.8656
#
# epoch: 45
#
# training time 9.18
# Training loss: 0.211535
#         task:      micro        macro
#       task_1:     0.9303,     0.8798
#       task_2:     0.9291,     0.9271
#       task_3:     0.9836,     0.9562
#       task_4:     0.8825,     0.8713
#
# epoch 45 validation
#
# epoch 45 val loss: 0.26351438, best val loss: 0.26068287
# patience counter is at 2 of 5
#         task:      micro        macro
#       task_1:     0.9413,     0.8918
#       task_2:     0.9327,     0.9311
#       task_3:     0.9747,     0.9422
#       task_4:     0.8747,     0.8647
#
# epoch: 46
#
# training time 9.15
# Training loss: 0.166815
#         task:      micro        macro
#       task_1:     0.9255,     0.8750
#       task_2:     0.9304,     0.9285
#       task_3:     0.9831,     0.9547
#       task_4:     0.8783,     0.8671
#
# epoch 46 validation
#
# epoch 46 val loss: 0.25057713, best val loss: 0.26068287
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9433,     0.8978
#       task_2:     0.9333,     0.9318
#       task_3:     0.9740,     0.9406
#       task_4:     0.8793,     0.8708
#
# epoch: 47
# training time 9.18
# Training loss: 0.175752
#         task:      micro        macro
#       task_1:     0.9297,     0.8785
#       task_2:     0.9297,     0.9278
#       task_3:     0.9843,     0.9580
#       task_4:     0.8865,     0.8737
#
# epoch 47 validation
#
# epoch 47 val loss: 0.25636195, best val loss: 0.25057713
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9467,     0.9064
#       task_2:     0.9313,     0.9299
#       task_3:     0.9740,     0.9408
#       task_4:     0.8780,     0.8670
#
# epoch: 48
#
# training time 9.17
# Training loss: 0.184777
#         task:      micro        macro
#       task_1:     0.9368,     0.8913
#       task_2:     0.9261,     0.9243
#       task_3:     0.9841,     0.9576
#       task_4:     0.8881,     0.8767
#
# epoch 48 validation
#
# epoch 48 val loss: 0.25074327, best val loss: 0.25057713
# patience counter is at 2 of 5
#         task:      micro        macro
#       task_1:     0.9453,     0.9040
#       task_2:     0.9333,     0.9316
#       task_3:     0.9747,     0.9425
#       task_4:     0.8867,     0.8763
#
# epoch: 49
#
# training time 9.16
# Training loss: 0.171589
#         task:      micro        macro
#       task_1:     0.9368,     0.8908
#       task_2:     0.9319,     0.9300
#       task_3:     0.9849,     0.9601
#       task_4:     0.8909,     0.8798
#
# epoch 49 validation
#
# epoch 49 val loss: 0.24903288, best val loss: 0.25057713
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9467,     0.9071
#       task_2:     0.9360,     0.9345
#       task_3:     0.9740,     0.9406
#       task_4:     0.8893,     0.8799
#
# epoch: 50
#
# training time 9.15
# Training loss: 0.179302
#         task:      micro        macro
#       task_1:     0.9348,     0.8909
#       task_2:     0.9273,     0.9253
#       task_3:     0.9852,     0.9606
#       task_4:     0.8947,     0.8839
#
# epoch 50 validation
#
# epoch 50 val loss: 0.24651592, best val loss: 0.24903288
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9480,     0.9095
#       task_2:     0.9347,     0.9332
#       task_3:     0.9773,     0.9476
#       task_4:     0.8933,     0.8829
#
# epoch: 51
#
# training time 9.18
# Training loss: 0.122909
#         task:      micro        macro
#       task_1:     0.9369,     0.8928
#       task_2:     0.9307,     0.9288
#       task_3:     0.9833,     0.9559
#       task_4:     0.8952,     0.8851
#
# epoch 51 validation
#
# epoch 51 val loss: 0.24664766, best val loss: 0.24651592
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9487,     0.9110
#       task_2:     0.9380,     0.9366
#       task_3:     0.9753,     0.9434
#       task_4:     0.8973,     0.8855
#
# epoch: 52
#
# training time 9.13
# Training loss: 0.157219
#         task:      micro        macro
#       task_1:     0.9413,     0.9008
#       task_2:     0.9291,     0.9273
#       task_3:     0.9856,     0.9616
#       task_4:     0.9005,     0.8905
#
# epoch 52 validation
#
# epoch 52 val loss: 0.24874841, best val loss: 0.24651592
# patience counter is at 2 of 5
#         task:      micro        macro
#       task_1:     0.9473,     0.9082
#       task_2:     0.9353,     0.9341
#       task_3:     0.9760,     0.9448
#       task_4:     0.8960,     0.8827
#
# epoch: 53
#
# training time 9.14
# Training loss: 0.178406
#         task:      micro        macro
#       task_1:     0.9373,     0.8964
#       task_2:     0.9328,     0.9311
#       task_3:     0.9856,     0.9620
#       task_4:     0.9048,     0.8962
#
# epoch 53 validation
#
# epoch 53 val loss: 0.24316254, best val loss: 0.24651592
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9487,     0.9125
#       task_2:     0.9387,     0.9372
#       task_3:     0.9767,     0.9462
#       task_4:     0.9000,     0.8881
#
# epoch: 54
#
# training time 9.16
# Training loss: 0.172110
#         task:      micro        macro
#       task_1:     0.9364,     0.8918
#       task_2:     0.9329,     0.9311
#       task_3:     0.9865,     0.9643
#       task_4:     0.9008,     0.8925
#
# epoch 54 validation
#
# epoch 54 val loss: 0.24032290, best val loss: 0.24316254
# patience counter is at 0 of 5
#         task:      micro        macro
#       task_1:     0.9513,     0.9168
#       task_2:     0.9380,     0.9367
#       task_3:     0.9760,     0.9450
#       task_4:     0.9080,     0.9001
#
# epoch: 55
#
# training time 9.14
# Training loss: 0.249174
#         task:      micro        macro
#       task_1:     0.9405,     0.8991
#       task_2:     0.9299,     0.9280
#       task_3:     0.9863,     0.9639
#       task_4:     0.9007,     0.8926
#
# epoch 55 validation
#
# epoch 55 val loss: 0.24649479, best val loss: 0.24032290
# patience counter is at 1 of 5
#         task:      micro        macro
#       task_1:     0.9507,     0.9167
#       task_2:     0.9380,     0.9367
#       task_3:     0.9747,     0.9422
#       task_4:     0.9020,     0.8919
#
# epoch: 56
#
# training time 9.16
# Training loss: 0.204211
#         task:      micro        macro
#       task_1:     0.9415,     0.8997
#       task_2:     0.9307,     0.9289
#       task_3:     0.9859,     0.9625
#       task_4:     0.9035,     0.8949
#
# epoch 56 validation
#
# epoch 56 val loss: 0.24249115, best val loss: 0.24032290
# patience counter is at 2 of 5
#         task:      micro        macro
#       task_1:     0.9500,     0.9150
#       task_2:     0.9360,     0.9344
#       task_3:     0.9760,     0.9453
#       task_4:     0.9087,     0.8989
#
# epoch: 57
#
# training time 9.15
# Training loss: 0.153199
#         task:      micro        macro
#       task_1:     0.9449,     0.9090
#       task_2:     0.9367,     0.9350
#       task_3:     0.9875,     0.9668
#       task_4:     0.9085,     0.9002
#
# epoch 57 validation
#
# epoch 57 val loss: 0.24438102, best val loss: 0.24032290
# patience counter is at 3 of 5
#         task:      micro        macro
#       task_1:     0.9500,     0.9154
#       task_2:     0.9367,     0.9353
#       task_3:     0.9760,     0.9450
#       task_4:     0.9067,     0.8979
#
# epoch: 58
#
# training time 9.15
# Training loss: 0.127457
#         task:      micro        macro
#       task_1:     0.9441,     0.9051
#       task_2:     0.9339,     0.9323
#       task_3:     0.9877,     0.9677
#       task_4:     0.9115,     0.9013
#
# epoch 58 validation
#
# epoch 58 val loss: 0.24337328, best val loss: 0.24032290
# patience counter is at 4 of 5
#         task:      micro        macro
#       task_1:     0.9493,     0.9125
#       task_2:     0.9360,     0.9345
#       task_3:     0.9760,     0.9450
#       task_4:     0.9060,     0.8950
#
# epoch: 59
#
# training time 9.17
# Training loss: 0.197810
#         task:      micro        macro
#       task_1:     0.9451,     0.9098
#       task_2:     0.9359,     0.9342
#       task_3:     0.9869,     0.9654
#       task_4:     0.9128,     0.9036
#
# epoch 59 validation
#
# epoch 59 val loss: 0.24229207, best val loss: 0.24032290
# patience counter is at 5 of 5
#         task:      micro        macro
#       task_1:     0.9507,     0.9162
#       task_2:     0.9380,     0.9366
#       task_3:     0.9773,     0.9478
#       task_4:     0.9100,     0.8989
# saving to savedmodels/P3B3_model/P3B3_model_fold0.h5
#
# Scoring test set
#
# Predicting train set
#
# Predicting val set
#
# Predicting test set
# Saving predictions to csv
#
# Evaluating train set
#
# Evaluating val set
#
# Evaluating test set
# Saving predictions to csv
#
# Full model file has been saved at savedmodels/P3B3_model/P3B3_model_20230523140343_fold0.h5
